# %% [markdown]
# ##### Name - Shunottara Alhat
#
#
# # Assignment 5 - Q.1. - Prepare a prediction model for profit of 50_startups data. Do transformations for getting better predictions of profit and make a table containing R^2 value for each prepared model.
# # R&D Spend -- Research and devolop spend in the past few years
# # Administration -- spend on administration in the past few years
# # Marketing Spend -- spend on Marketing in the past few years
# # State -- states from which data is collected
# # Profit  -- profit of each state in the past few years

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot
import scipy.stats as stat
import pylab

# %%
# Import Dataset

Startups = pd.read_csv("50_Startups.csv")
Startups
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ### EDA

# %%
# Dataset Info
Startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# Rename Dataset
startups = Startups.rename({'R&D Spend':'RDS','Administration':'Admin','Marketing Spend':'MRKTS'},axis = 1)
startups
# Out:
#           RDS      Admin      MRKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
# Duplicate of Dataset
startups[startups.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RDS, Admin, MRKTS, State, Profit]
# Index: []

# %%
# Described Dataset
startups.describe()
# Out:
#                  RDS          Admin          MRKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %% [markdown]
# ### Correlation Analysis

# %%
startups.corr()
# Out:
#              RDS     Admin     MRKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# Admin   0.241955  1.000000 -0.032154  0.200717
# MRKTS   0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
# Visualizing Dataset
sns.pairplot(startups)

# %% [markdown]
# ## Model Building

# %%
model = smf.ols('Profit ~ RDS + Admin + MRKTS', data = startups).fit()

# %%
discrete_feature = [feature for feature in startups.columns if len(startups[feature].unique())<20 and feature]
print('Discrete Variables Count: {}'.format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 1

# %%
continuous_feature = [feature for feature in startups.columns if startups[feature].dtype != 'O']
print('Continuous Feature Count: {}'.format(len(continuous_feature)))
# Out:
# Continuous Feature Count: 4

# %% [markdown]
# #### LOG

# %%
ml_p=smf.ols('Profit ~ RDS + Admin + MRKTS',data = startups).fit()
print(ml_p.tvalues, '\n', ml_p.pvalues)
# Out:
# Intercept     7.626218
# RDS          17.846374
# Admin        -0.525507
# MRKTS         1.655077
# dtype: float64
#  Intercept    1.057379e-09
# RDS          2.634968e-22
# Admin        6.017551e-01
# MRKTS        1.047168e-01
# dtype: float64

# %%
def plot_data(startups,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    startups[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(startups[feature],dist='norm',plot = pylab)


plot_data(startups,'Profit')
plt.title('Profit')
# Out:
# Text(0.5, 1.0, 'Profit')

# %%
plot_data(startups,'RDS')
plt.title('RDS')
# Out:
# Text(0.5, 1.0, 'RDS')

# %%
plot_data(startups,'Admin')
plt.title('Admin')
# Out:
# Text(0.5, 1.0, 'Admin')

# %%
plot_data(startups,'MRKTS')
plt.title('MRKTS')
# Out:
# Text(0.5, 1.0, 'MRKTS')

# %%
df_Log = startups.copy()
df_Log[continuous_feature] = np.log(df_Log[continuous_feature])

plot_data(startups,'Profit')
plt.title('Profit')

plot_data(startups,'RDS')
plt.title('RDS')

plot_data(startups,'Admin')
plt.title('Admin')

plot_data(startups,'MRKTS')
plt.title('MRKTS')
# Out:
# C:\Users\Shunottara\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# Text(0.5, 1.0, 'MRKTS')

# %% [markdown]
# #### Square

# %%
df_Sqr = startups.copy()
df_Sqr[continuous_feature] = np.square(df_Sqr[continuous_feature])

plot_data(df_Sqr,'Profit')
plt.title('Profit')

plot_data(df_Sqr,'RDS')
plt.title('RDS')

plot_data(df_Sqr,'Admin')
plt.title('Admin')

plot_data(df_Sqr,'MRKTS')
plt.title('MRKTS')
# Out:
# Text(0.5, 1.0, 'MRKTS')

# %% [markdown]
# #### SquareRoot

# %%
df_Sqrt = startups.copy()
df_Sqrt[continuous_feature] = np.sqrt(df_Sqrt[continuous_feature])

plot_data(df_Sqrt,'Profit')
plt.title('Profit')

plot_data(df_Sqrt,'RDS')
plt.title('RDS')

plot_data(df_Sqrt,'Admin')
plt.title('Admin')

plot_data(df_Sqrt,'MRKTS')
plt.title('MRKTS')
# Out:
# Text(0.5, 1.0, 'MRKTS')

# %%
for feature in continuous_feature:
    data = startups.copy()
    data.boxplot(column = feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Finding Coefficient Parameters
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# Admin           -0.026816
# MRKTS            0.027228
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , np.round(model.pvalues, 5)
# Out:
# (Intercept     7.626218
#  RDS          17.846374
#  Admin        -0.525507
#  MRKTS         1.655077
#  dtype: float64,
#  Intercept    0.00000
#  RDS          0.00000
#  Admin        0.60176
#  MRKTS        0.10472
#  dtype: float64)

# %%
# Finding RSquared Values
model.rsquared , model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
# Build SLR for insignificant variables 'Admin' and 'MRKTS'
slr_a = smf.ols("Profit ~ Admin", data = startups).fit()

# %%
# find their tvalues and pvalues
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    3.040044
#  Admin        1.419493
#  dtype: float64,
#  Intercept    0.003824
#  Admin        0.162217
#  dtype: float64)

# %%
slr_m = smf.ols("Profit ~ MRKTS", data = startups).fit()
slr_m.tvalues , slr_m.pvalues
# Out:
# (Intercept    7.808356
#  MRKTS        7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MRKTS        4.381073e-10
#  dtype: float64)

# %%
# Build MLR models for insignificant variables 'Admin' and 'MRKTS'
mlr_am = smf.ols("Profit ~ Admin + MRKTS", data = startups).fit()
mlr_am.tvalues , mlr_am.pvalues
# Out:
# (Intercept    1.142741
#  Admin        2.467779
#  MRKTS        8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  Admin        1.729198e-02
#  MRKTS        9.727245e-11
#  dtype: float64)

# %% [markdown]
# ## Model Validation
#
# ### Two Techniques: 1. Collinearity Check & 2. Residual Analysis

# %%
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

Rsq_r = smf.ols("RDS ~ Admin + MRKTS", data = startups).fit().rsquared
VIF_r = 1/(1-Rsq_r)

Rsq_a = smf.ols("Admin ~ RDS + MRKTS", data = startups).fit().rsquared
VIF_a = 1/(1-Rsq_a)

Rsq_m = smf.ols("MRKTS ~ RDS + Admin", data = startups).fit().rsquared
VIF_m = 1/(1-Rsq_m)

# %%
# Put Values in DataFrame Format

df = {'Variables': ['RDS','Admin','MRKTS'],'VIF':[VIF_r,VIF_a,VIF_m]}
VIF_df = pd.DataFrame(df)
VIF_df
# Out:
#   Variables       VIF
# 0       RDS  2.468903
# 1     Admin  1.175091
# 2     MRKTS  2.326773

# %%
# 2) Residual Analysis 
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)

sm.qqplot(model.resid,line = 'q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity

def standard_values(svals) : return (svals - svals.mean())/svals.std()

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardize Fitted Values')
plt.ylabel('Standardize Residual Values')
plt.show()

# %%
fig = plt.figure(figsize = (12,6))
sm.graphics.plot_regress_exog(model,'RDS' , fig = fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize = (12,6))
sm.graphics.plot_regress_exog(model, 'Admin',fig = fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize = (12,6))
sm.graphics.plot_regress_exog(model, 'MRKTS',fig = fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics
# ### Two Techniques : 1. Cook's Distance & 2. Leverage Value

# %%
(c,_) = model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the Influencers Using the stem Plot
fig = plt.figure(figsize =(18,6))
plt.stem(np.arange(len(startups)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and Value of Influencer 
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543263)

# %%
# Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k = startups.shape[1]
n = startups.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
startups[startups.index.isin([49])]
# Out:
#     RDS     Admin     MRKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# ### Improving Model

# %%
startups = startups.drop(startups.index[[49]],axis = 0).reset_index(drop = True)
startups
# Out:
#           RDS      Admin      MRKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# ### Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>0.5 :
    model = smf.ols("Profit ~ RDS + Admin + MRKTS", data = startups).fit()
    (c,_) = model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    startups = startups.drop(startups.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
else:
    final_model = smf.ols("Profit ~ RDS + Admin + MRKTS", data = startups).fit()
    final_model.rsquared , final_model.aic
    print("Model Accuracy is Improved to",final_model.rsquared)
# Out:
# Model Accuracy is Improved to 0.9613162435129847

# %%
final_model.rsquared
# Out:
# 0.9613162435129847

# %%
startups
# Out:
#           RDS      Admin      MRKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# ### Model Prediction

# %%
Newdata = pd.DataFrame({"RDS": 70000 ,"Admin": 90000 ,"MRKTS": 140000},index = [0])
Newdata
# Out:
#      RDS  Admin   MRKTS
# 0  70000  90000  140000

# %%
# Manual Prediction 
Pred = final_model.predict(Newdata)
Pred
# Out:
# 0    108727.154753
# dtype: float64

# %%
# Automatics Prediction 
pred_y = final_model.predict(startups)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %% [markdown]
# ### Table Containing R^2 Value for Each Prepared Model

# %%
d2 = {'PrepModels':['Model','FinalModel'], 'Rsquared':[model.rsquared,final_model.rsquared]}
Table = pd.DataFrame(d2)
Table
# Out:
#    PrepModels  Rsquared
# 0       Model  0.950746
# 1  FinalModel  0.961316
